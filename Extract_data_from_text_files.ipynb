# %%
f = open("/home/ficiu/Desktop/asd", "r")

# %%
import matplotlib.pyplot as plt

# %%
f
# Out:
# <_io.TextIOWrapper name='/home/ficiu/Desktop/asd' mode='r' encoding='UTF-8'>

# %%
a=f.readlines()

# %%
a[29].split(' ')[6]
# Out:
# '0.8854170645615725'

# %%
acc=[]
validation=[]
for each in range(len(a)-1):
    acc.append(float(a[each].split(' ')[6]))
    validation.append(float(a[each].split(' ')[10]))

# %%
plt.plot(acc)
plt.plot(validation)
plt.title('Model accuracy')
plt.ylabel('Percent')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
validation
# Out:
# ['0.4735234168845621',
#  '0.47250508791681706',
#  '0.512983702320431',
#  '0.4753054940955459',
#  '0.4979633401828968',
#  '0.49490834720994203',
#  '0.48676170939826185',
#  '0.5119653756288307',
#  '0.5310590597070647',
#  '0.5068737232029559',
#  '0.5267311570418585',
#  '0.5318228056741586',
#  '0.5257128265566835',
#  '0.539714867313622',
#  '0.5397148650374771',
#  '0.548370666574315',
#  '0.5549898132105223',
#  '0.5654277003042081',
#  '0.5623727050551086',
#  '0.572046840870696',
#  '0.5723014238713472',
#  '0.5761201620526809',
#  '0.5784114022301073',
#  '0.5913951094670111',
#  '0.5980142561032185',
#  '0.6025967432865057',
#  '0.6053971464303749',
#  '0.6127800382749612',
#  '0.6193991849111685',
#  '0.6237270860589449',
#  '0.6283095724835173',
#  '0.6288187415196793',
#  '0.6308553994551696',
#  '0.6390020403017095',
#  '0.6466395121120873',
#  '0.6537678224734522',
#  '0.6588594733818971',
#  '0.66140529428383',
#  '0.6682790224032586',
#  '0.6710794331342771',
# ...

# %%
plt.plot(b)
plt.plot(a)
plt.title('Model accuracy')
plt.ylabel('Percent')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
a=[0.64,0.6830323063911781,0.72,0.73467311104634,0.7546425843717972,0.7719833816693937,0.7822273062774616,0.7994917372130378,0.8145510028318969,0.8322309800244808, 0.8460951429645412, 0.8595219935711305, 0.8556543871892907, 0.8672093653672829, 0.8861612830869237, 0.9006190151393155, 0.9022374803893233, 0.923252864592866, 0.9297888581002526, 0.9263546192078941, 0.9101161714790128, 0.9324942809948024, 0.9428208407483227, 0.9430170483760207, 0.9372933080438377, 0.9453913339229775, 0.9460971316338314, 0.9484116958390348, 0.959933862465388,0.9382684676790524,0.962242567445254,0.9786314028451473,0.9771050728480344,0.9669295453463237]
b=[0.67,0.71,0.7333723323604784,0.7602818116023036,0.77,0.7841518909481172,0.8089884762016042,0.8327949730653857,0.8524048110701792,0.8732354962049885,0.884477452198262,0.8923875177962026,0.9074191840093927,0.9180380001004321,0.92668565828275,0.931581760297536,0.9398351868981095,0.9439682598640612,0.9524633142680545,0.9561258530808989,0.9589872115213273,0.9608184808140493,0.965244048599928,0.9668718435352142,0.969199081247298,0.9753668986972085,0.9757229790311713,0.9748200608357367, 0.9737645379523766,0.9778976118279293,0.9777704389048553,0.97784674291642,0.9831370744663479,0.9829463183790408]

# %%
len(a),len(b)
# Out:
# (34, 34)
